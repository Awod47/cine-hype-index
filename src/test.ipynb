# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in e:\dev projects\cine-hype-index\venv\lib\site-packages (7.1.0)
# Requirement already satisfied: comm>=0.1.1 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: wcwidth in e:\dev projects\cine-hype-index\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: six>=1.5 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in e:\dev projects\cine-hype-index\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in e:\dev projects\cine-hype-index\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

import googleapiclient.discovery
import pandas as pd

import datetime
from dateutil.parser import isoparse

# %%
import datetime

movies = {
    "Heretic": {
        "id": "O9i2vmFhSSY",
        "release_date": datetime.datetime(2024, 11, 21, tzinfo=datetime.timezone.utc)
    },
    "Dune Part 2": {
        "id": "Way9Dexny3w",
        "release_date": datetime.datetime(2024, 3, 1, tzinfo=datetime.timezone.utc)
    },
    "Nosferatu": {
        "id": "nulvWqYUM8k",
        "release_date": datetime.datetime(2024, 12, 25, tzinfo=datetime.timezone.utc)
    },
    "Godzilla X Kong": {
        "id": "lV1OOlGwExM",
        "release_date": datetime.datetime(2024, 4, 12, tzinfo=datetime.timezone.utc)
    },
    "Fall guy": {
        "id": "j7jPnwVGdZ8",
        "release_date": datetime.datetime(2024, 5, 3, tzinfo=datetime.timezone.utc)
    },
    "Kingdom of the Planet of the Apes": {
        "id": "XtFI7SNtVpY",
        "release_date": datetime.datetime(2024, 5, 10, tzinfo=datetime.timezone.utc)
    },
    "Bad Boys 4": {
        "id": "hRFY_Fesa9Q",
        "release_date": datetime.datetime(2024, 6, 5, tzinfo=datetime.timezone.utc)
    },
    "Lisa Frankenstein": {
        "id": "POOeA3zCuUY",
        "release_date": datetime.datetime(2024, 2, 9, tzinfo=datetime.timezone.utc)
    },
    "Deadpool 3": {
        "id": "73_1biulkYk",
        "release_date": datetime.datetime(2024, 7, 26, tzinfo=datetime.timezone.utc)
    },
    "Alien Romulus": {
        "id": "OzY2r2JXsDM",
        "release_date": datetime.datetime(2024, 8, 16, tzinfo=datetime.timezone.utc)
    },
    "Transformers One": {
        "id": "0rmJXXKDrsM",
        "release_date": datetime.datetime(2024, 9, 13, tzinfo=datetime.timezone.utc)
    },
    "Joker Folie à Deux": {
        "id": "_OKAwz2MsJs",
        "release_date": datetime.datetime(2024, 10, 4, tzinfo=datetime.timezone.utc)
    },
    "Smile 2": {
        "id": "0HY6QFlBzUY",
        "release_date": datetime.datetime(2024, 10, 18, tzinfo=datetime.timezone.utc)
    },
    "Venom 3": {
        "id": "__2bjWbetsA",
        "release_date": datetime.datetime(2024, 10, 25, tzinfo=datetime.timezone.utc)
    },
    "Red One": {
        "id": "U8XH3W0cMss",
        "release_date": datetime.datetime(2024, 11, 15, tzinfo=datetime.timezone.utc)
    },
    "The Book of Clarence": {
        "id": "aTMqRPOqkGs",
        "release_date": datetime.datetime(2024, 1, 12, tzinfo=datetime.timezone.utc)
    },
    "Madame Web": {
        "id": "s_76M4c4LTo",
        "release_date": datetime.datetime(2024, 2, 14, tzinfo=datetime.timezone.utc)
    },
    "Road House": {
        "id": "Y0ZsLudtfjI",
        "release_date": datetime.datetime(2024, 3, 21, tzinfo=datetime.timezone.utc)
    },
    "Gladiator 2": {
        "id": "4rgYUipGJNo",
        "release_date": datetime.datetime(2024, 11, 22, tzinfo=datetime.timezone.utc)
    },
    "Mufasa The lion king": {
        "id": "o17MF9vnabg",
        "release_date": datetime.datetime(2024, 12, 20, tzinfo=datetime.timezone.utc)
    },
    "Sonic the hedgehog 3": {
        "id": "qSu6i2iFMO0",
        "release_date": datetime.datetime(2024, 12, 20, tzinfo=datetime.timezone.utc)
    },
    "Wicked": {
        "id": "6COmYeLsz4c",
        "release_date": datetime.datetime(2024, 12, 5, tzinfo=datetime.timezone.utc)
    },
    "Mean girls": {
        "id": "fFtdbEgnUOk",
        "release_date": datetime.datetime(2024, 1, 12, tzinfo=datetime.timezone.utc)
    },
    "Kraven the hunter": {
        "id": "I8gFw4-2RBM",
        "release_date": datetime.datetime(2024, 12, 13, tzinfo=datetime.timezone.utc)
    },
    "Borderlands": {
        "id": "lU_NKNZljoQ",
        "release_date": datetime.datetime(2024, 8, 9, tzinfo=datetime.timezone.utc)
    },
}

# %%
load_dotenv()
api_service_name = "youtube"
api_version = "v3"
developer_key = os.getenv('API_KEY')

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=developer_key
)

for key,value in movies.items():
    print(key, value['id'], value['release_date'])

    release_date = value['release_date']
    window_start = release_date - datetime.timedelta(days=120)
    window_end   = release_date + datetime.timedelta(days=120)


    comments = []
    next_page_token = None

    while True:

        request = youtube.commentThreads().list(
            part="snippet",
            videoId= value['id'],
            maxResults=200,
            pageToken=next_page_token,
            order="time"  
        )
        response = request.execute()

        stop_fetching = False

        for item in response["items"]:
            c = item["snippet"]["topLevelComment"]["snippet"]
            ts = isoparse(c["publishedAt"])

            if ts > window_end:
                continue

            if ts < window_start:
                stop_fetching = True
                break

            # Inside window → save
            comments.append([
                c["authorDisplayName"],
                c["publishedAt"],
                c["updatedAt"],
                c["likeCount"],
                c["textDisplay"]
            ])

        if stop_fetching:
            break

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    df = pd.DataFrame(
        comments,
        columns=["author", "published_at", "updated_at", "like_count", "text"]
    )

    df.to_csv(f"../comments/{key}.csv", index=False)
# Out:
# Heretic O9i2vmFhSSY 2024-11-21 00:00:00+00:00
# Dune Part 2 Way9Dexny3w 2024-03-01 00:00:00+00:00
# Nosferatu nulvWqYUM8k 2024-12-25 00:00:00+00:00
# Godzilla X Kong lV1OOlGwExM 2024-04-12 00:00:00+00:00
# Fall guy j7jPnwVGdZ8 2024-05-03 00:00:00+00:00
# Kingdom of the Planet of the Apes XtFI7SNtVpY 2024-05-10 00:00:00+00:00
# Bad Boys 4 hRFY_Fesa9Q 2024-06-05 00:00:00+00:00
# A Quiet Place Day One YPY7J-flzE8 2024-06-27 00:00:00+00:00
# Deadpool 3 73_1biulkYk 2024-07-26 00:00:00+00:00
# Alien Romulus OzY2r2JXsDM 2024-08-16 00:00:00+00:00
# Transformers One 0rmJXXKDrsM 2024-09-13 00:00:00+00:00
# Joker Folie à Deux _OKAwz2MsJs 2024-10-04 00:00:00+00:00
# Smile 2 0HY6QFlBzUY 2024-10-18 00:00:00+00:00
# Venom 3 __2bjWbetsA 2024-10-25 00:00:00+00:00
# Red One U8XH3W0cMss 2024-11-15 00:00:00+00:00
# The Book of Clarence aTMqRPOqkGs 2024-01-12 00:00:00+00:00
# Madame Web s_76M4c4LTo 2024-02-14 00:00:00+00:00
# Road House Y0ZsLudtfjI 2024-03-21 00:00:00+00:00
# Gladiator 2 4rgYUipGJNo 2024-11-22 00:00:00+00:00
# Mufasa The lion king o17MF9vnabg 2024-12-20 00:00:00+00:00
# Sonic the hedgehog 3 qSu6i2iFMO0 2024-12-20 00:00:00+00:00
# Wicked 6COmYeLsz4c 2024-12-05 00:00:00+00:00
# Mean girls fFtdbEgnUOk 2024-01-12 00:00:00+00:00
# Kraven the hunter I8gFw4-2RBM 2024-12-13 00:00:00+00:00
# Borderlands lU_NKNZljoQ 2024-08-09 00:00:00+00:00
